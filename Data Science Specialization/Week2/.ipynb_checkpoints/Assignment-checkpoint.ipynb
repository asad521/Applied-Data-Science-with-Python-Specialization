# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("olympics.csv")

# %%
df.head(4)
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70

# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

names_ids = df.index.str.split('\s\(') # split the index by '('

df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df = df.drop('Totals')
df.head(4)
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
#
#              Combined total   ID
# Afghanistan               2  AFG
# Algeria                  15  ALG
# Argentina                70  ARG
# Armenia                  12  ARM

# %%
df['Gold'].idxmax()
# Out:
# 'United States'

# %% [markdown]
# # Question 3
# Which country has the biggest difference between their summer gold medal counts and winter gold medal counts relative to their total gold medal count?
#
# Summer Gold−Winter GoldTotal Gold
# Summer Gold−Winter GoldTotal Gold
#
# Only include countries that have won at least 1 gold in both summer and winter.
#
# This function should return a single string value.

# %%
df1=df[(df['Gold'] != 0) & df['Gold.2'] !=0]

# %%
formula=abs((df1['Gold']-df1['Gold.2'])/(df1['Combined total']))
type(formula)
formula.idxmax()
# Out:
# 'Austria'

# %% [markdown]
# # Question 4
# ##Write a function that creates a Series called "Points" which is a weighted value where each gold medal (Gold.2) counts for 3 points, silver medals (Silver.2) for 2 points, and bronze medals (Bronze.2) for 1 point. The function should return only the column (a Series object) which you created, with the country names as indices.
#
# This function should return a Series named Points of length 146

# %%
print(df.shape)
df.head(2)
# Out:
# (146, 16)
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
#
#              Combined total   ID
# Afghanistan               2  AFG
# Algeria                  15  ALG

# %%
s1=df['Gold.2']*3 + df['Silver.2']*2 +df['Bronze.2']*1
print(type(s1))
print(s1.shape)
print(s1)
# Out:
# <class 'pandas.core.series.Series'>
# (146,)
# Afghanistan                           2
# Algeria                              27
# Argentina                           130
# Armenia                              16
# Australasia                          22
#                                    ...
# Yugoslavia                          171
# Independent Olympic Participants      4
# Zambia                                3
# Zimbabwe                             18
# Mixed team                           38
# Length: 146, dtype: int64

# %% [markdown]
# # Part 2

# %% [markdown]
# Which state has the most counties in it? (hint: consider the sumlevel key carefully! You'll need this for future questions too...)
#
# This function should return a single string value.

# %%
df = pd.read_csv('census.csv')
print(df.shape)
df.head(3)
# Out:
# (3193, 100)
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# ...

# %%
d1=df[df['STNAME']=="Alabama"]
d1.head(4)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
# ...

# %%
d1['CTYNAME'].count()
# Out:
# 68

# %%
df['STNAME'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
st=[]
county=[]
for ST in df['STNAME'].unique():
    d1=df[df['STNAME']==ST]
    county_count=d1['CTYNAME'].count()
    st.append(ST)
    county.append(county_count)
    
s1=pd.Series(data=county, index=st)
s1.idxmax()
# Out:
# 'Texas'

# %%
def answer_five():
    st=[]
    county=[]
    for ST in df['STNAME'].unique():
        d1=df[df['STNAME']==ST]
        county_count=d1['CTYNAME'].count()
        st.append(ST)
        county.append(county_count)
        s1=pd.Series(data=county, index=st)
        return s1.idxmax()

# %%
answer_five()
# Out:
# 'Alabama'

# %% [markdown]
# # ### Question 6
# **Only looking at the three most populous counties for each state**, what are the three most populous states (in order of highest population to lowest population)? Use `CENSUS2010POP`.
#
# *This function should return a list of string values.*

# %%
df = pd.read_csv('census.csv')
print(cdf.shape)
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-49b6708a9991> in <module>
#       1 df = pd.read_csv('census.csv')
# ----> 2 print(cdf.shape)
#       3 df.head(3)
#
# NameError: name 'cdf' is not defined

# %%
df1=df.set_index('STNAME')

df1
# Out:
#          SUMLEV  REGION  DIVISION  STATE  COUNTY            CTYNAME  \
# STNAME
# Alabama      40       3         6      1       0            Alabama
# Alabama      50       3         6      1       1     Autauga County
# Alabama      50       3         6      1       3     Baldwin County
# Alabama      50       3         6      1       5     Barbour County
# Alabama      50       3         6      1       7        Bibb County
# ...         ...     ...       ...    ...     ...                ...
# Wyoming      50       4         8     56      37  Sweetwater County
# Wyoming      50       4         8     56      39       Teton County
# Wyoming      50       4         8     56      41       Uinta County
# Wyoming      50       4         8     56      43    Washakie County
# Wyoming      50       4         8     56      45      Weston County
#
#          CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME
# ...

# %%
# d={}
# a=[]
# for ST in df1.index.unique():
#     a=df1.loc[ST]
#     B=a['CENSUS2010POP'].nlargest(3)
#     d[ST]=[B.values]
    
df = pd.read_csv('census.csv')
print(cdf.shape)
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-14dd36e666bc> in <module>
#       7
#       8 df = pd.read_csv('census.csv')
# ----> 9 print(cdf.shape)
#      10 df.head(3)
#
# NameError: name 'cdf' is not defined

# %%
# # b=df['STATE']==1
# # a=df['STNAME']=='Alabama'
# # df[a&b]
# b=df['CENSUS2010POP'].nlargest(3)
# a=df['STNAME']=='Alabama'
# a=df[a]
# a
# a.loc[a['CENSUS2010POP'].nlargest(3).,df['CTYNAME']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-336-d279099731fe> in <module>
#       6 a=df[a]
#       7 a
# ----> 8 a.loc[a['CENSUS2010POP'].nlargest(3).index(),df['CTYNAME']]
#
# TypeError: 'Int64Index' object is not callable

# %%
df1=df.set_index(['STNAME','CTYNAME'])
df1.head(3)
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Alabama             40       3         6      1       0
#         Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Alabama               4779736            4780127          4785161
#         Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# STNAME  CTYNAME                                           ...
# Alabama Alabama                 4801108          4816089  ...
#         Autauga County            55253            55175  ...
#         Baldwin County           186659           190396  ...
#
# ...

# %%
df1.loc[('Alabama')].head(3)
# Out:
#                 SUMLEV  REGION  DIVISION  STATE  COUNTY  CENSUS2010POP  \
# CTYNAME
# Alabama             40       3         6      1       0        4779736
# Autauga County      50       3         6      1       1          54571
# Baldwin County      50       3         6      1       3         182265
#
#                 ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# CTYNAME
# Alabama                   4780127          4785161          4801108
# Autauga County              54571            54660            55253
# Baldwin County             182265           183193           186659
#
#                 POPESTIMATE2012  ...  RDOMESTICMIG2011  RDOMESTICMIG2012  \
# CTYNAME                          ...
# Alabama                 4816089  ...          0.002295         -0.193196
# Autauga County            55175  ...          7.242091         -2.915927
# Baldwin County           190396  ...         14.832960         17.647293
#
# ...

# %%
# df1.loc[df1['Alabama'],df1['CENSUS2010POP']]
# df.loc[1:5,['total_bill','sex','day']]

# %%
# d={}
# for i in df['STNAME'].unique():
#     m1=df[df['STNAME']==ST]
#     final
#     final=df[m1&m2]
# final
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     273         #  (xint or xbool) and (yint or bool)
# --> 274         result = op(x, y)
#     275     except TypeError:
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     287             try:
# --> 288                 result = libops.scalar_binop(x, y, op)
#     289             except (
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_binop()
#
# ...

# %%
d={}
m1=df[df['STNAME']=='Alabama']
m2=m1[['CENSUS2010POP','CTYNAME']]
m3=m2.set_index('CTYNAME')
m3['CENSUS2010POP'].nlargest(3)
ind=pd.Series(m3['CENSUS2010POP'].nlargest(3).index)
m3['CENSUS2010POP'].nlargest(3).values
a=str(ind.values)
d[a]=str(m3['CENSUS2010POP'].nlargest(3).values)
# ======

# m1=df[df['STNAME']=='Texas']
# m2=m1[['CENSUS2010POP','CTYNAME']]
# m3=m2.set_index('CTYNAME')
# m3['CENSUS2010POP'].nlargest(3)
# ind=pd.Series(m3['CENSUS2010POP'].nlargest(3).index)
# m3['CENSUS2010POP'].nlargest(3).values
# b=str(ind.values)
# d[b]=str(m3['CENSUS2010POP'].nlargest(3).values)
# d
# Out:
# {"['Alabama' 'Jefferson County' 'Mobile County']": '[4779736  658466  412992]',
#  "['Texas' 'Harris County' 'Dallas County']": '[25145561  4092459  2368139]'}

# %%
d={}
l=[]
largest=0
largest_index=0
for d in df['STNAME'].unique():
    m1=df[df['STNAME']==d]
    m2=m1[['CENSUS2010POP','CTYNAME']]
    m3=m2.set_index('CTYNAME')
    cur_large=m3['CENSUS2010POP'].nlargest(3).sum()
    cur_large_index=m3['CENSUS2010POP'].nlargest(3).index
    print(cur_large)
    print(largest)
    if cur_large > largest:
        largest=cur_large
        print(largest)
        print("end first loop")
        largest_index=cur_large_index
print(largest_index)
# Out:
# 5851194
# 0
# 5851194
# end first loop
# 1099638
# 5851194
# 11189397
# 5851194
# 11189397
# end first loop
# 3520005
# 11189397
# 50167874
# 11189397
# 50167874
# end first loop
# 6251617
# 50167874
# 5384940
# 50167874
# 1633558
# 50167874
# 1203446
# 50167874
# 23045811
# 50167874
# 11413555
# 50167874
# 2498587
# 50167874
# 2148870
# 50167874
# 18942231
# 50167874
# 7883200
# 50167874
# 3688221
# 50167874
# 3895662
# 50167874
# 5376266
# 50167874
# 5406095
# 50167874
# 1807166
# 50167874
# 7608749
# 50167874
# 8849266
# 50167874
# 12906586
# 50167874
# 6964990
# 50167874
# 3399687
# 50167874
# 7662039
# 50167874
# 1246686
# 50167874
# 2628858
# 50167874
# 5073227
# 50167874
# 2012414
# 50167874
# 10506868
# 50167874
# 2930976
# 50167874
# 24113524
# 50167874
# 11356104
# 50167874
# 903677
# 50167874
# 13980040
# 50167874
# 5073387
# 50167874
# 5096118
# 50167874
# 15451733
# 50167874
# 1845392
# 50167874
# 5461093
# 50167874
# 1084596
# 50167874
# 7900430
# 50167874
# 31606159
# ...

# %%
# d={}
# largest=[]
# largest_index=[]
# for d in df['STNAME'].unique():
#     m1=df[df['STNAME']==d]
#     m2=m1[['CENSUS2010POP','CTYNAME']]
#     m3=m2.set_index('CTYNAME')
#     cur_large=m3['CENSUS2010POP'].nlargest(3).tolist()
#     cur_large_index=m3['CENSUS2010POP'].nlargest(3).index
#     print("Current is "+str(cur_large))
#     print("Cur Index is "+str(cur_large_index))
#     if  cur_large>largest:
#         largest=cur_large
#         largest_index=cur_large_index
# #         print("Condition\n")
#         print("Largest"+str(largest))
#         print("Largest index"+str(largest_index))
#         print("end\n")
    
        
cur_large
largest_index
# Out:
# Current is [4779736, 658466, 412992]
# Cur Index is Index(['Alabama', 'Jefferson County', 'Mobile County'], dtype='object', name='CTYNAME')
# Largest[4779736, 658466, 412992]
# Largest indexIndex(['Alabama', 'Jefferson County', 'Mobile County'], dtype='object', name='CTYNAME')
# end
#
# Current is [710231, 291826, 97581]
# Cur Index is Index(['Alaska', 'Anchorage Municipality', 'Fairbanks North Star Borough'], dtype='object', name='CTYNAME')
# Current is [6392017, 3817117, 980263]
# Cur Index is Index(['Arizona', 'Maricopa County', 'Pima County'], dtype='object', name='CTYNAME')
# Largest[6392017, 3817117, 980263]
# Largest indexIndex(['Arizona', 'Maricopa County', 'Pima County'], dtype='object', name='CTYNAME')
# end
#
# Current is [2915918, 382748, 221339]
# Cur Index is Index(['Arkansas', 'Pulaski County', 'Benton County'], dtype='object', name='CTYNAME')
# Current is [37253956, 9818605, 3095313]
# ...

# %%
# df = pd.read_csv('census.csv')
# df.head(3)
# df=df[df['SUMLEV']==50]
# df2=df[['STNAME','CTYNAME','CENSUS2010POP']]
# df2=df2.set_index(['STNAME','CTYNAME'])
# df2.head(3)
# answer=df2['CENSUS2010POP'].nlargest(3).index.get_level_values(0).tolist()
# answer
# # idx.get_level_values(0)
# # 
def answer_six():
    df61=census_df[census_df['SUMLEV']==50]
    df62=df[['STNAME','CTYNAME','CENSUS2010POP']]
#     df63=df62.set_index(['STNAME','CTYNAME'])
#     df63.head(3)
#     answer=df63['CENSUS2010POP'].nlargest(3).index.get_level_values(0).tolist()
#     return answer
# answer_six()

# %%
df['CENSUS2010POP'].nlargest(3).index.tolist()
df.iloc[[190, 2566, 1860]]
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME     CTYNAME  \
# 190       40       4         9      6       0  California  California
# 2566      40       3         7     48       0       Texas       Texas
# 1860      40       1         2     36       0    New York    New York
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# 190        37253956           37254503         37334079  ...
# 2566       25145561           25146105         25244363  ...
# 1860       19378102           19378087         19402920  ...
#
#       RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 190          -1.148464         -1.163788         -1.339869         -0.862856
# 2566          4.527491          5.484904          4.446476          6.072953
# 1860         -4.354557         -5.945385         -5.561401         -8.130297
#
#       RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
# ...

# %%
df[df['CTYNAME']=='Illinois']
# Out:
#      SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME   CTYNAME  \
# 608      40       2         3     17       0  Illinois  Illinois
#
#      CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 608       12830632           12831549         12841249  ...          -5.24333
#
#      RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 608         -5.805172          -5.30896         -7.509147         -8.174675
#
#      RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 608     -3.02041    -3.519051    -2.830379    -4.625216     -5.24703
#
# [1 rows x 100 columns]

# %%
census_df = pd.read_csv('census.csv')
df.head(3)
st=[]
county=[]
df51=census_df[census_df['SUMLEV']==50]
for ST in df51['STNAME'].unique():
    df52=df[df51['STNAME']==ST]
    county_count=df52['CTYNAME'].count()
    county.append(county_count)
    st.append(ST)

s1=pd.Series(data=county, index=st)
s1.idxmax()
# Out:
# 'Texas'

# %%
# verification
a=df[df51['STNAME']=='Texas']
a['CTYNAME'].count()
# Out:
# 254
