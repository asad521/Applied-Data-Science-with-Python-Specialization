# %%
import pandas as pd
import numpy as np

# %%
s1=pd.Series({'Name':'Asad','Purchases':3434,'Return':23})
s2=pd.Series({'Name':'Bob','Purchases':999,'Return':88})
s3=pd.Series({'Name':'Jhon','Purchases':888,'Return':99})
df=pd.DataFrame([s1,s1,s3], index=['Store1','Store1','Store2'])
df
# Out:
#         Name  Purchases  Return
# Store1  Asad       3434      23
# Store1  Asad       3434      23
# Store2  Jhon        888      99

# %%
df.loc['Store1']
# Out:
#         Name  Purchases  Return
# Store1  Asad       3434      23
# Store1  Asad       3434      23

# %%
df.loc['Store1','Return']
# Out:
# Store1    23
# Store1    23
# Name: Return, dtype: int64

# %%
df.T
# Out:
#           Store1 Store1 Store2
# Name        Asad   Asad   Jhon
# Purchases   3434   3434    888
# Return        23     23     99

# %%
df['Return']
# Out:
# Store1    23
# Store1    23
# Store2    99
# Name: Return, dtype: int64

# %%
df.drop('Return',axis=1)
# Out:
#         Name  Purchases
# Store1  Asad       3434
# Store1  Asad       3434
# Store2  Jhon        888

# %%
df
# Out:
#         Name  Purchases  Return
# Store1  Asad       3434      23
# Store1  Asad       3434      23
# Store2  Jhon        888      99

# %%
dfcopy=df.copy()
dfcopy
# Out:
#         Name  Purchases  Return
# Store1  Asad       3434      23
# Store1  Asad       3434      23
# Store2  Jhon        888      99

# %%
del dfcopy['Return']
dfcopy
# Out:
#         Name  Purchases
# Store1  Asad       3434
# Store1  Asad       3434
# Store2  Jhon        888

# %%
df['LOCATION']=None

# %%
df
# Out:
#         Name  Purchases  Return LOCATION
# Store1  Asad       3434      23     None
# Store1  Asad       3434      23     None
# Store2  Jhon        888      99     None

# %% [markdown]
# # DataFrame Indexing and Loading

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])


df['Name'][df['Cost']>3]
# Out:
# Store 1    Chris
# Store 2    Vinod
# Name: Name, dtype: object

# %%
df.loc[df['Cost']>3,['Cost']]
# Out:
#          Cost
# Store 1  22.5
# Store 2   5.0

# %%
df=pd.read_csv("census.csv")
df.head(6)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# ...

# %%
df['SUMLEV'].unique()
df1=df[df['SUMLEV']==50]
df1
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df1.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
keep_col=['STNAME', 'CTYNAME',
       'POPESTIMATE2010',
       'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
       'POPESTIMATE2014', 'POPESTIMATE2015',     
       'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
       'BIRTHS2015']

# %%
df3=df[keep_col]
df3.head()
# Out:
#     STNAME         CTYNAME  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0  Alabama         Alabama          4785161          4801108          4816089
# 1  Alabama  Autauga County            54660            55253            55175
# 2  Alabama  Baldwin County           183193           186659           190396
# 3  Alabama  Barbour County            27341            27226            27159
# 4  Alabama     Bibb County            22861            22733            22642
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  BIRTHS2010  BIRTHS2011  \
# 0          4830533          4846411          4858979       14226       59689
# 1            55038            55290            55347         151         636
# 2           195126           199713           203709         517        2187
# 3            26973            26815            26489          70         335
# 4            22512            22549            22583          44         266
#
# ...

# %%
df4=df3.set_index(['STNAME','CTYNAME'])
df4.index   #What is this. What is benefit of this double index in this type of data.
df4
#In original df3, STNAME have multiple STNAME entries with respective CTYNAME .
#Set index make all Alabama state in STNAME to only one index entry,
#Then it goes to CTYNAME, and assign all entries in CTYNAME of respective state(index of state).
# Out:
#                            POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# STNAME  CTYNAME
# Alabama Alabama                    4785161          4801108          4816089
#         Autauga County               54660            55253            55175
#         Baldwin County              183193           186659           190396
#         Barbour County               27341            27226            27159
#         Bibb County                  22861            22733            22642
# ...                                    ...              ...              ...
# Wyoming Sweetwater County            43593            44041            45104
#         Teton County                 21297            21482            21697
#         Uinta County                 21102            20912            20989
#         Washakie County               8545             8469             8443
#         Weston County                 7181             7114             7065
#
# ...

# %%
df4.index
# Out:
# MultiIndex([('Alabama',           'Alabama'),
#             ('Alabama',    'Autauga County'),
#             ('Alabama',    'Baldwin County'),
#             ('Alabama',    'Barbour County'),
#             ('Alabama',       'Bibb County'),
#             ('Alabama',     'Blount County'),
#             ('Alabama',    'Bullock County'),
#             ('Alabama',     'Butler County'),
#             ('Alabama',    'Calhoun County'),
#             ('Alabama',   'Chambers County'),
#             ...
#             ('Wyoming',   'Niobrara County'),
#             ('Wyoming',       'Park County'),
#             ('Wyoming',     'Platte County'),
#             ('Wyoming',   'Sheridan County'),
#             ('Wyoming',   'Sublette County'),
#             ('Wyoming', 'Sweetwater County'),
#             ('Wyoming',      'Teton County'),
#             ('Wyoming',      'Uinta County'),
#             ('Wyoming',   'Washakie County'),
#             ('Wyoming',     'Weston County')],
# ...

# %%
df3
# Out:
#        STNAME            CTYNAME  POPESTIMATE2010  POPESTIMATE2011  \
# 0     Alabama            Alabama          4785161          4801108
# 1     Alabama     Autauga County            54660            55253
# 2     Alabama     Baldwin County           183193           186659
# 3     Alabama     Barbour County            27341            27226
# 4     Alabama        Bibb County            22861            22733
# ...       ...                ...              ...              ...
# 3188  Wyoming  Sweetwater County            43593            44041
# 3189  Wyoming       Teton County            21297            21482
# 3190  Wyoming       Uinta County            21102            20912
# 3191  Wyoming    Washakie County             8545             8469
# 3192  Wyoming      Weston County             7181             7114
#
#       POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# 0             4816089          4830533          4846411          4858979
# ...

# %% [markdown]
# # Query with multiindex

# %%
df4.head(3)
# Out:
#                         POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# STNAME  CTYNAME
# Alabama Alabama                 4785161          4801108          4816089
#         Autauga County            54660            55253            55175
#         Baldwin County           183193           186659           190396
#
#                         POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# STNAME  CTYNAME
# Alabama Alabama                 4830533          4846411          4858979
#         Autauga County            55038            55290            55347
#         Baldwin County           195126           199713           203709
#
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Alabama              14226       59689       59062       57938
#         Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#
# ...

# %%
df4.loc[('Alabama','Baldwin County')] #one raw query  #same as one level query. just provide  both index in ()
# Out:
# C:\Users\ZEESHAN123\anaconda3\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                         POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# STNAME  CTYNAME
# Alabama Baldwin County           183193           186659           190396
#
#                         POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# STNAME  CTYNAME
# Alabama Baldwin County           195126           199713           203709
#
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Baldwin County         517        2187        2092        2160
#
#                         BIRTHS2014  BIRTHS2015
# STNAME  CTYNAME
# Alabama Baldwin County        2186        2240

# %%
df4.loc[[('Alabama','Baldwin County'),('Alabama','Autauga County')]]
# Out:
#                         POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# STNAME  CTYNAME
# Alabama Baldwin County           183193           186659           190396
#         Autauga County            54660            55253            55175
#
#                         POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# STNAME  CTYNAME
# Alabama Baldwin County           195126           199713           203709
#         Autauga County            55038            55290            55347
#
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Baldwin County         517        2187        2092        2160
#         Autauga County         151         636         615         574
#
#                         BIRTHS2014  BIRTHS2015
# STNAME  CTYNAME
# Alabama Baldwin County        2186        2240
#         Autauga County         623         600

# %%
df4.loc[[('Alabama','Baldwin County'),('Michigan','Washtenaw County')]]
# Out:
#                            POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# STNAME   CTYNAME
# Alabama  Baldwin County             183193           186659           190396
# Michigan Washtenaw County           345563           349048           351213
#
#                            POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# STNAME   CTYNAME
# Alabama  Baldwin County             195126           199713           203709
# Michigan Washtenaw County           354289           357029           358880
#
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Alabama  Baldwin County           517        2187        2092        2160
# Michigan Washtenaw County         977        3826        3780        3662
#
#                            BIRTHS2014  BIRTHS2015
# STNAME   CTYNAME
# Alabama  Baldwin County          2186        2240
# Michigan Washtenaw County        3683        3709

# %%
df4.loc[[('Alabama','Baldwin County'),('Michigan','Washtenaw County')],['POPESTIMATE2010','POPESTIMATE2011']]
# Out:
#                            POPESTIMATE2010  POPESTIMATE2011
# STNAME   CTYNAME
# Alabama  Baldwin County             183193           186659
# Michigan Washtenaw County           345563           349048

# %% [markdown]
# # Assignment

# %% [markdown]
# # Assignment
# Reindex the purchase records DataFrame to be indexed hierarchically, first by store, then by person. Name these indexes 'Location' and 'Name'. Then add a new entry to it with the value of:
# Name: 'Kevyn', Item Purchased: 'Kitty Food', Cost: 3.00 Location: 'Store 2'

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df['location']=df.index
df2=df.set_index(['location','Name'])
df2
# Out:
#                Item Purchased  Cost
# location Name
# Store 1  Chris       Dog Food  22.5
#          Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
# Assignment
Reindex the purchase records DataFrame to be indexed hierarchically, first by store, then by person. Name these indexes 'Location' and 'Name'. Then add a new entry to it with the value of:
Name: 'Kevyn', Item Purchased: 'Kitty Food', Cost: 3.00 Location: 'Store 2'

# %%
entry={'Name': 'Kevyn', 'Item Purchased': 'Kitty Food', 'Cost': 3.00 }

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df = df.set_index([df.index, 'Name'])
df
# Out:
#               Item Purchased  Cost
#         Name
# Store 1 Chris       Dog Food  22.5
#         Kevyn   Kitty Litter   2.5
# Store 2 Vinod      Bird Seed   5.0

# %%
df.index.names = ['Location', 'Name']
df
# Out:
#                Item Purchased  Cost
# Location Name
# Store 1  Chris       Dog Food  22.5
#          Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df = df.append(pd.Series(data={'Cost': 3.00, 'Item Purchased': 'Kitty Food'}, name=('Store 2', 'Kevyn')))
df
# Out:
#                Item Purchased  Cost
# Location Name
# Store 1  Chris       Dog Food  22.5
#          Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0
#          Kevyn     Kitty Food   3.0

# %%
df3 = df.append(pd.Series(data={'Cost': 3.00, 'Item Purchased': 'Kitty Food'}, name=('Store 4', 'Kevyn')))
df3
# Out:
#                Item Purchased  Cost
# Location Name
# Store 1  Chris       Dog Food  22.5
#          Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0
#          Kevyn     Kitty Food   3.0
# Store 4  Kevyn     Kitty Food   3.0
